# %% [markdown]
# <a href="https://colab.research.google.com/github/chetannitk/NLP-Experiments/blob/master/Huggingface_tests.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
# Out:
# ...
#      |████████████████████████████████| 573kB 8.6MB/s
# ...
#      |████████████████████████████████| 1.0MB 55.3MB/s
# ...
#      |████████████████████████████████| 3.7MB 53.7MB/s
# ...
#      |████████████████████████████████| 890kB 50.5MB/s
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.41-cp36-none-any.whl size=893334 sha256=465c7965b4b8558c6a12daf52dad60726f4a92b058f8ba0b0938bcfd8801f77a
#   Stored in directory: /root/.cache/pip/wheels/22/5a/d4/b020a81249de7dc63758a34222feaa668dbe8ebfe9170cc9b1
# Successfully built sacremoses
# ...

# %%
from transformers import pipeline

nlp = pipeline("question-answering")

context = r"""
Extractive Question Answering is the task of extracting an answer from a text given a question. An example of a
question answering dataset is the SQuAD dataset, which is entirely based on that task. If you would like to fine-tune
a model on a SQuAD task, you may leverage the `run_squad.py`.
"""

print(nlp(question="What is extractive question answering?", context=context))
print(nlp(question="What is a good example of a question answering dataset?", context=context))
# Out:
# ...
# add example index and unique id: 100%|██████████| 1/1 [00:00<00:00, 478.53it/s]
# {'score': 0.6222322754670984, 'start': 34, 'end': 96, 'answer': 'the task of extracting an answer from a text given a question.'}
# ...
# add example index and unique id: 100%|██████████| 1/1 [00:00<00:00, 5737.76it/s]
# {'score': 0.51152867118412, 'start': 147, 'end': 161, 'answer': 'SQuAD dataset,'}

# %%
from transformers import pipeline

nlp = pipeline("sentiment-analysis")

print(nlp("I hate you"))
print(nlp("I love you"))
# Out:
# ...
# [{'label': 'NEGATIVE', 'score': 0.9991129}]
# [{'label': 'POSITIVE', 'score': 0.99986565}]

# %%
print(nlp("The movie is good not bad at all"))
# Out:
# [{'label': 'POSITIVE', 'score': 0.99968845}]

# %%
print(nlp("The movie is bad not good at all"))
# Out:
# [{'label': 'NEGATIVE', 'score': 0.9998022}]

# %%
from transformers import pipeline

nlp = pipeline("fill-mask")
print(nlp(f"HuggingFace is creating a {nlp.tokenizer.mask_token} that the community uses to solve NLP tasks."))
# Out:
# ...
# [{'sequence': '<s> HuggingFace is creating a tool that the community uses to solve NLP tasks.</s>', 'score': 0.1572081595659256, 'token': 3944}, {'sequence': '<s> HuggingFace is creating a framework that the community uses to solve NLP tasks.</s>', 'score': 0.11565092206001282, 'token': 7208}, {'sequence': '<s> HuggingFace is creating a library that the community uses to solve NLP tasks.</s>', 'score': 0.05949186533689499, 'token': 5560}, {'sequence': '<s> HuggingFace is creating a database that the community uses to solve NLP tasks.</s>', 'score': 0.04147873446345329, 'token': 8503}, {'sequence': '<s> HuggingFace is creating a prototype that the community uses to solve NLP tasks.</s>', 'score': 0.025827836245298386, 'token': 17715}]

# %%
print(nlp(f"what is {nlp.tokenizer.mask_token} name."))
# Out:
# [{'sequence': '<s> what is thy name.</s>', 'score': 0.2650415897369385, 'token': 32667}, {'sequence': '<s> what is my name.</s>', 'score': 0.17488500475883484, 'token': 127}, {'sequence': '<s> what is his name.</s>', 'score': 0.17151042819023132, 'token': 39}, {'sequence': '<s> what is your name.</s>', 'score': 0.1436070054769516, 'token': 110}, {'sequence': '<s> what is her name.</s>', 'score': 0.1006203219294548, 'token': 69}]

# %%
print(nlp(f"hope you are {nlp.tokenizer.mask_token} good"))
# Out:
# [{'sequence': '<s> hope you are feeling good</s>', 'score': 0.765138566493988, 'token': 2157}, {'sequence': '<s> hope you are doing good</s>', 'score': 0.07726895809173584, 'token': 608}, {'sequence': '<s> hope you are looking good</s>', 'score': 0.05132497474551201, 'token': 546}, {'sequence': '<s> hope you are very good</s>', 'score': 0.01902490109205246, 'token': 182}, {'sequence': '<s> hope you are really good</s>', 'score': 0.018996944651007652, 'token': 269}]

# %%
from transformers import pipeline

translator = pipeline("translation_en_to_de")
print(translator("Hugging Face is a technology company based in New York and Paris", max_length=40))
# Out:
# ...
# [{'translation_text': 'Hugging Face ist ein Technologieunternehmen mit Sitz in New York und Paris.'}]
